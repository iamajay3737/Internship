# %% [markdown]
# # Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
# For downloading the dataset, use the link given below.
#
# # Dataset Link-
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %% [markdown]
# # Evaluation Project-1

# %% [markdown]
# # Baseball Case Study

# %% [raw]
# Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
#
# For downloading the dataset, use the link given below.

# %%
import pandas as pd
import numpy as np
import scipy
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor



from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# Here w i.e. is win , our target variable. Rest all other 16 columns are input/features variables.

# %% [markdown]
# To get better understanding of columns we will replace it by their full forms

# %%
df.rename(columns={'W':'Wins','R':'Runs','AB':'At Bats','H':'Hits','2B':"Doubles",'3B':"Triples",
                   'HR':'HomeRuns','BB':'Walks','SO':'Strike Outs','SB':'Stolen Bases','RA':'Runs Allowed',
                   'ER':'Earned Runs','ERA':'Earned Run Average (ERA)','CG':'Complete Games','SHO':'Shutouts','SV':'Saves',
                   'E':"Errors"}, inplace=True)
df
# Out:
#     Wins  Runs  At Bats  Hits  Doubles  Triples  HomeRuns  Walks  Strike Outs  \
# 0     95   724     5575  1497      300       42       139    383          973
# 1     83   696     5467  1349      277       44       156    439         1264
# 2     81   669     5439  1395      303       29       141    533         1157
# 3     76   622     5533  1381      260       27       136    404         1231
# 4     74   689     5605  1515      289       49       151    455         1259
# 5     93   891     5509  1480      308       17       232    570         1151
# 6     87   764     5567  1397      272       19       212    554         1227
# 7     81   713     5485  1370      246       20       217    418         1331
# 8     80   644     5485  1383      278       32       167    436         1310
# 9     78   748     5640  1495      294       33       161    478         1148
# 10    88   751     5511  1419      279       32       172    503         1233
# 11    86   729     5459  1363      278       26       230    486         1392
# 12    85   661     5417  1331      243       21       176    435         1150
# 13    76   656     5544  1379      262       22       198    478         1336
# 14    68   694     5600  1405      277       46       146    475         1119
# 15   100   647     5484  1386      288       39       137    506         1267
# 16    98   697     5631  1462      292       27       140    461         1322
# 17    97   689     5491  1341      272       30       171    567         1518
# 18    68   655     5480  1378      274       34       145    412         1299
# 19    64   640     5571  1382      257       27       167    496         1255
# 20    90   683     5527  1351      295       17       177    488         1290
# 21    83   703     5428  1363      265       13       177    539         1344
# 22    71   613     5463  1420      236       40       120    375         1150
# 23    67   573     5420  1361      251       18       100    471         1107
# 24    63   626     5529  1374      272       37       130    387         1274
# 25    92   667     5385  1346      263       26       187    563         1258
# 26    84   696     5565  1486      288       39       136    457         1159
# 27    79   720     5649  1494      289       48       154    490         1312
# 28    74   650     5457  1324      260       36       148    426         1327
# 29    68   737     5572  1479      274       49       186    388         1283
#
#     Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average (ERA)  \
# 0            104           641          601                      3.73
# 1             70           700          653                      4.07
# 2             86           640          584                      3.67
# 3             68           701          643                      3.98
# 4             83           803          746                      4.64
# 5             88           670          609                      3.80
# 6             63           698          652                      4.03
# 7             44           693          646                      4.05
# 8             87           642          604                      3.74
# 9             71           753          694                      4.31
# 10           101           733          680                      4.24
# 11           121           618          572                      3.57
# 12            52           675          630                      3.94
# 13            69           726          677                      4.16
# 14            78           729          664                      4.14
# 15            69           525          478                      2.94
# 16            98           596          532                      3.21
# 17            95           608          546                      3.36
# 18            84           737          682                      4.28
# 19           134           754          700                      4.33
# 20            51           613          557                      3.43
# 21            57           635          577                      3.62
# 22           112           678          638                      4.02
# 23            69           760          698                      4.41
# 24            88           809          749                      4.69
# 25            59           595          553                      3.44
# 26            93           627          597                      3.72
# 27           132           713          659                      4.04
# 28            82           731          655                      4.09
# 29            97           844          799                      5.04
#
#     Complete Games  Shutouts  Saves  Errors
# 0                2         8     56      88
# 1                2        12     45      86
# 2               11        10     38      79
# 3                7         9     37     101
# 4                7        12     35      86
# 5                7        10     34      88
# 6                3         4     48      93
# 7                0        10     43      77
# 8                1        12     60      95
# 9                3        10     40      97
# 10               5         9     45     119
# 11               5        13     39      85
# 12               2        12     46      93
# 13               6        12     45      94
# 14               5        15     28     126
# 15               1        15     62      96
# 16               0        13     54     122
# 17               6        21     48     111
# 18               1         7     40     116
# 19               2         8     35      90
# 20               1        14     50      88
# 21               4        13     41      90
# 22               0        12     35      77
# 23               3        10     44      90
# 24               1         7     35     117
# 25               6        21     47      75
# 26               7        18     41      78
# 27               1        12     44      86
# 28               1         6     41      92
# 29               4         4     36      95

# %%
df.head(10)
# Out:
#    Wins  Runs  At Bats  Hits  Doubles  Triples  HomeRuns  Walks  Strike Outs  \
# 0    95   724     5575  1497      300       42       139    383          973
# 1    83   696     5467  1349      277       44       156    439         1264
# 2    81   669     5439  1395      303       29       141    533         1157
# 3    76   622     5533  1381      260       27       136    404         1231
# 4    74   689     5605  1515      289       49       151    455         1259
# 5    93   891     5509  1480      308       17       232    570         1151
# 6    87   764     5567  1397      272       19       212    554         1227
# 7    81   713     5485  1370      246       20       217    418         1331
# 8    80   644     5485  1383      278       32       167    436         1310
# 9    78   748     5640  1495      294       33       161    478         1148
#
#    Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average (ERA)  \
# 0           104           641          601                      3.73
# 1            70           700          653                      4.07
# 2            86           640          584                      3.67
# 3            68           701          643                      3.98
# 4            83           803          746                      4.64
# 5            88           670          609                      3.80
# 6            63           698          652                      4.03
# 7            44           693          646                      4.05
# 8            87           642          604                      3.74
# 9            71           753          694                      4.31
#
#    Complete Games  Shutouts  Saves  Errors
# 0               2         8     56      88
# 1               2        12     45      86
# 2              11        10     38      79
# 3               7         9     37     101
# 4               7        12     35      86
# 5               7        10     34      88
# 6               3         4     48      93
# 7               0        10     43      77
# 8               1        12     60      95
# 9               3        10     40      97

# %%
df.tail(10)
# Out:
#     Wins  Runs  At Bats  Hits  Doubles  Triples  HomeRuns  Walks  Strike Outs  \
# 20    90   683     5527  1351      295       17       177    488         1290
# 21    83   703     5428  1363      265       13       177    539         1344
# 22    71   613     5463  1420      236       40       120    375         1150
# 23    67   573     5420  1361      251       18       100    471         1107
# 24    63   626     5529  1374      272       37       130    387         1274
# 25    92   667     5385  1346      263       26       187    563         1258
# 26    84   696     5565  1486      288       39       136    457         1159
# 27    79   720     5649  1494      289       48       154    490         1312
# 28    74   650     5457  1324      260       36       148    426         1327
# 29    68   737     5572  1479      274       49       186    388         1283
#
#     Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average (ERA)  \
# 20            51           613          557                      3.43
# 21            57           635          577                      3.62
# 22           112           678          638                      4.02
# 23            69           760          698                      4.41
# 24            88           809          749                      4.69
# 25            59           595          553                      3.44
# 26            93           627          597                      3.72
# 27           132           713          659                      4.04
# 28            82           731          655                      4.09
# 29            97           844          799                      5.04
#
#     Complete Games  Shutouts  Saves  Errors
# 20               1        14     50      88
# 21               4        13     41      90
# 22               0        12     35      77
# 23               3        10     44      90
# 24               1         7     35     117
# 25               6        21     47      75
# 26               7        18     41      78
# 27               1        12     44      86
# 28               1         6     41      92
# 29               4         4     36      95

# %%
df.sample(10)
# Out:
#     Wins  Runs  At Bats  Hits  Doubles  Triples  HomeRuns  Walks  Strike Outs  \
# 5     93   891     5509  1480      308       17       232    570         1151
# 7     81   713     5485  1370      246       20       217    418         1331
# 17    97   689     5491  1341      272       30       171    567         1518
# 18    68   655     5480  1378      274       34       145    412         1299
# 4     74   689     5605  1515      289       49       151    455         1259
# 10    88   751     5511  1419      279       32       172    503         1233
# 21    83   703     5428  1363      265       13       177    539         1344
# 11    86   729     5459  1363      278       26       230    486         1392
# 9     78   748     5640  1495      294       33       161    478         1148
# 6     87   764     5567  1397      272       19       212    554         1227
#
#     Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average (ERA)  \
# 5             88           670          609                      3.80
# 7             44           693          646                      4.05
# 17            95           608          546                      3.36
# 18            84           737          682                      4.28
# 4             83           803          746                      4.64
# 10           101           733          680                      4.24
# 21            57           635          577                      3.62
# 11           121           618          572                      3.57
# 9             71           753          694                      4.31
# 6             63           698          652                      4.03
#
#     Complete Games  Shutouts  Saves  Errors
# 5                7        10     34      88
# 7                0        10     43      77
# 17               6        21     48     111
# 18               1         7     40     116
# 4                7        12     35      86
# 10               5         9     45     119
# 21               4        13     41      90
# 11               5        13     39      85
# 9                3        10     40      97
# 6                3         4     48      93

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Dataset contains 30 rows and 17 columns

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Wins                      30 non-null     int64
#  1   Runs                      30 non-null     int64
#  2   At Bats                   30 non-null     int64
#  3   Hits                      30 non-null     int64
#  4   Doubles                   30 non-null     int64
#  5   Triples                   30 non-null     int64
#  6   HomeRuns                  30 non-null     int64
#  7   Walks                     30 non-null     int64
#  8   Strike Outs               30 non-null     int64
#  9   Stolen Bases              30 non-null     int64
#  10  Runs Allowed              30 non-null     int64
#  11  Earned Runs               30 non-null     int64
#  12  Earned Run Average (ERA)  30 non-null     float64
#  13  Complete Games            30 non-null     int64
#  14  Shutouts                  30 non-null     int64
#  15  Saves                     30 non-null     int64
#  16  Errors                    30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# All 16 columns are of integer datatype and 1 column ERA is float datatype

# %%
df.describe().T
# Out:
#                           count         mean         std      min        25%  \
# Wins                       30.0    80.966667   10.453455    63.00    74.0000
# Runs                       30.0   688.233333   58.761754   573.00   651.2500
# At Bats                    30.0  5516.266667   70.467372  5385.00  5464.0000
# Hits                       30.0  1403.533333   57.140923  1324.00  1363.0000
# Doubles                    30.0   274.733333   18.095405   236.00   262.2500
# Triples                    30.0    31.300000   10.452355    13.00    23.0000
# HomeRuns                   30.0   163.633333   31.823309   100.00   140.2500
# Walks                      30.0   469.100000   57.053725   375.00   428.2500
# Strike Outs                30.0  1248.200000  103.759470   973.00  1157.5000
# Stolen Bases               30.0    83.500000   22.815225    44.00    69.0000
# Runs Allowed               30.0   688.233333   72.108005   525.00   636.2500
# Earned Runs                30.0   635.833333   70.140786   478.00   587.2500
# Earned Run Average (ERA)   30.0     3.956333    0.454089     2.94     3.6825
# Complete Games             30.0     3.466667    2.763473     0.00     1.0000
# Shutouts                   30.0    11.300000    4.120177     4.00     9.0000
# Saves                      30.0    43.066667    7.869335    28.00    37.2500
# Errors                     30.0    94.333333   13.958889    75.00    86.0000
#
#                                50%      75%      max
# Wins                        81.000    87.75   100.00
# Runs                       689.000   718.25   891.00
# At Bats                   5510.000  5570.00  5649.00
# Hits                      1382.500  1451.50  1515.00
# Doubles                    275.500   288.75   308.00
# Triples                     31.000    39.00    49.00
# HomeRuns                   158.500   177.00   232.00
# Walks                      473.000   501.25   570.00
# Strike Outs               1261.500  1311.50  1518.00
# Stolen Bases                83.500    96.50   134.00
# Runs Allowed               695.500   732.50   844.00
# Earned Runs                644.500   679.25   799.00
# Earned Run Average (ERA)     4.025     4.22     5.04
# Complete Games               3.000     5.75    11.00
# Shutouts                    12.000    13.00    21.00
# Saves                       42.000    46.75    62.00
# Errors                      91.000    96.75   126.00

# %% [raw]
# Obs:
#     The counts of all the columns are same, this means there are no null values present in any of the columns
#     Mean>Median columns: At Bats,Hits,Triples,HomeRuns, CompleteGame, Saves,Error. These are right skewed
#     Median >mean columns: Wins,Runs,Doubles,Walks,Strike Outs,Runs Allowed, Earned runs,ERA, Shutouts. These are left skewed
#     Max diff between max and 75%: Wins, runs, At bats,hits,doubles triples, homeruns, walks, Strike..hence we see all columns        have difference. it shows that columns have outliers

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Wins                        0
# Runs                        0
# At Bats                     0
# Hits                        0
# Doubles                     0
# Triples                     0
# HomeRuns                    0
# Walks                       0
# Strike Outs                 0
# Stolen Bases                0
# Runs Allowed                0
# Earned Runs                 0
# Earned Run Average (ERA)    0
# Complete Games              0
# Shutouts                    0
# Saves                       0
# Errors                      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we have no null values in our dataset

# %% [markdown]
# # Checking duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# we have no duplicates in our dataset

# %% [markdown]
# # Checking unique values

# %%
df.nunique()
# Out:
# Wins                        24
# Runs                        28
# At Bats                     29
# Hits                        29
# Doubles                     22
# Triples                     23
# HomeRuns                    27
# Walks                       29
# Strike Outs                 29
# Stolen Bases                27
# Runs Allowed                30
# Earned Runs                 30
# Earned Run Average (ERA)    30
# Complete Games               9
# Shutouts                    12
# Saves                       20
# Errors                      21
# dtype: int64

# %% [raw]
# It shows that there are no categorical data since even the unique numbers are large in number and cannot be segregated or combined.

# %% [markdown]
# # visualization

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# • Distribution Plot

# %%
for i in df.columns:
    sns.displot(df,x=i,element='step',color= 'y')
    plt.show()

# %% [raw]
# observation:
#     1. No of wins are higher in the range of 76-83
#     2. No of runs are higher in the range of 650- 745
#     3. max no of at bats lies in range of 5445 - 5410
#     4. max no hits are given between 1370-1380
#     5. max double are between 260 -285
#     6. max triples are between 26-30
#     7. max home runs are between 165-185
#     8. max walks are between
#     9. max strike outs are between 1250- 1320
#     10.stolen bases 60- 90 are max
#     11.runs allowed are max in 680 - 740
#     12.earned runs are max between 640-690
#     13. ERA ia max in 3.8-4.2
#     14. maximum complete games are 2
#     15 shutouts are max in range 11-14
#     16. max saves are between 35-40

# %% [markdown]
# • Strip Plot

# %%
fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(15,15))
index = 0
features = df.drop("Wins", axis=1)
ax = ax.flatten()
for col, value in features.items():
    sns.stripplot(y=col, data=df, ax=ax[index], palette="viridis")
    index += 1
plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
plt.show()

# %% [markdown]
# As we can see columns Runs Scored, Strike Outs, Complete Game with single data points further away from the general accumulation indicating towards the presence of ouliers.

# %% [markdown]
# • Box Plot

# %%
fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(15,15))
index = 0
features = df.drop("Wins", axis=1)
ax = ax.flatten()
for col, value in features.items():
    sns.boxplot(y=col, data=df, ax=ax[index], palette='plasma')
    index += 1
plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
plt.show()

# %% [markdown]
# The above box plot representation clearly shows few outlier points present in Runs Scored, Earned Run Average, Shut Outs, Saves and Errors.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# • Line Plot

# %%
index = 0
features = df.drop("Wins", axis=1)
for col, value in features.items():
    sns.relplot(x=col, y="Wins", kind="line", data=df)
    index += 1
plt.show()

# %% [raw]
# All of the above features (except the errors) are positively correlated with our label
# As the number of runs increases then the chance of win increases
# As the doubles increase then the chance of win increases
# As the triples increases then the chance of win increases
# As the home runs increases then the chance of win increases
# As the walks on balls increases then the chance of win increases
# As the strike outs increases then the chance of win increases for the opposite team
# As the stolen bases increases then the chance of win increases again for the opposite team
# As the runs allowed decreases then the chance of win increases
# As the earned run and earned run average decreases the chance of win increases automatically
# saves and shutout are directly proportional to wins
# complete game and error shows a constant relation with wins

# %% [markdown]
# • Bar plot

# %%
col= df.drop(['Wins'],axis = 1)
for i in col:
    plt.figure(figsize=(10,10))
    sns.barplot(x=i, y="Wins", data=df)
    plt.show()

# %% [raw]
# Observation:
#     1. Runs unique values are distributed unevenly when it comes to relating with wins
#     2. At bats unique values are also distributed unevenly when compared with wins
#     3. Hits, Doubles, Triples, Homerun, Walks, strike out, stolen bases unique values are also unevenly distributed when related        with wins
#     4. runs allowed , earned runs, and ERA shows decreasing pattern of its unique values when related to wins
#     5. complete game unique values shows no pattern. They are random or distribuuted unevenly
#     6. Shuouts unique values also shows no pattern relating with wins. They are distributed unevenly
#     7. Saves uniques values show a slightly increasing pattern reated to wins
#     8. Error show uneven distribution and no pattern comparing to wins

# %% [markdown]
# • Joint Plot

# %%
col= df.drop(['Wins'],axis = 1)
for i in col:
    plt.figure(figsize=(10,10))
    sns.jointplot(x=i, y="Wins", data=df, color="purple")
    plt.show()

# %% [raw]
# observation:
#     1.  With increase in runs the chances of winning becomes higher
#     2. At bats shows no proper relation with wins as the points are very scattered
#     3. hits, doubles, triples also show no proper relationship with wins
#     4. in homeruns we can see with increase in homeruns the chances of wins are slight higher
#     5. no considerable relation found between walks and wins
#     6. stolen base and strike out also show no considerable relation with win
#     7. runs allowed, earned runs and earned runs average shows a inverse relation with wins
#     8. wins has incresed with increase in no of saves and shutouts
#     9. complete games and error has no  proper relation with wins

# %% [markdown]
# • LM Plot

# %%
for i in col:
    sns.lmplot(x = i , y ='Wins' , data = df)

# %% [raw]
# Observation:
#     1. Runs, doubles, homeruns, Walks, saves and shutouts are directly proportions to wins
#     2. Runs Allowed, Earned runs, Earned Runs avg, Error, stolen bases and triples are inversely proportional to wins
#     3. Whereas complete games, hits, At bats have constant relations with wins

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # • Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# As the graph shown above are very minute we will plot a correlation

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#                               Wins      Runs   At Bats      Hits   Doubles  \
# Wins                      1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                      0.430751  1.000000  0.319464  0.482856  0.560084
# At Bats                  -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                      0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles                   0.427797  0.560084  0.453370  0.566847  1.000000
# Triples                  -0.251118 -0.070072  0.435422  0.478694  0.220490
# HomeRuns                  0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks                     0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strike Outs               0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen Bases             -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs Allowed             -0.812952 -0.041623  0.316010  0.224324 -0.218160
# Earned Runs              -0.809435 -0.041245  0.309686  0.252489 -0.235531
# Earned Run Average (ERA) -0.819600 -0.049281  0.255551  0.231172 -0.254854
# Complete Games            0.080533  0.232042 -0.080876  0.147955  0.306675
# Shutouts                  0.471805 -0.103274 -0.197321 -0.145559  0.057998
# Saves                     0.666530 -0.096380 -0.106367 -0.130371  0.171576
# Errors                   -0.089485 -0.023262  0.316743 -0.033173  0.105754
#
#                            Triples  HomeRuns     Walks  Strike Outs  \
# Wins                     -0.251118  0.307407  0.484342     0.111850
# Runs                     -0.070072  0.671283  0.402452    -0.054726
# At Bats                   0.435422 -0.066983 -0.136414    -0.106022
# Hits                      0.478694 -0.090855 -0.118281    -0.398830
# Doubles                   0.220490  0.056292  0.302700    -0.150752
# Triples                   1.000000 -0.430915 -0.454949    -0.141196
# HomeRuns                 -0.430915  1.000000  0.425691     0.359923
# Walks                    -0.454949  0.425691  1.000000     0.233652
# Strike Outs              -0.141196  0.359923  0.233652     1.000000
# Stolen Bases              0.457437 -0.136567 -0.098347     0.030968
# Runs Allowed              0.314125 -0.103903 -0.416445    -0.129745
# Earned Runs               0.340225 -0.085922 -0.452663    -0.161612
# Earned Run Average (ERA)  0.330951 -0.090917 -0.459832    -0.180368
# Complete Games           -0.065898  0.156502  0.462478    -0.093418
# Shutouts                 -0.041396 -0.019119  0.426004     0.237721
# Saves                    -0.142370 -0.028540  0.099445     0.126297
# Errors                    0.126678 -0.207597 -0.075685     0.155133
#
#                           Stolen Bases  Runs Allowed  Earned Runs  \
# Wins                         -0.157234     -0.812952    -0.809435
# Runs                          0.081367     -0.041623    -0.041245
# At Bats                       0.372618      0.316010     0.309686
# Hits                          0.413444      0.224324     0.252489
# Doubles                       0.195027     -0.218160    -0.235531
# Triples                       0.457437      0.314125     0.340225
# HomeRuns                     -0.136567     -0.103903    -0.085922
# Walks                        -0.098347     -0.416445    -0.452663
# Strike Outs                   0.030968     -0.129745    -0.161612
# Stolen Bases                  1.000000      0.132290     0.143068
# Runs Allowed                  0.132290      1.000000     0.991018
# Earned Runs                   0.143068      0.991018     1.000000
# Earned Run Average (ERA)      0.126063      0.986674     0.997248
# Complete Games               -0.020783     -0.016659    -0.020221
# Shutouts                     -0.106563     -0.636862    -0.630192
# Saves                        -0.183418     -0.616224    -0.589663
# Errors                        0.079149      0.198996     0.136921
#
#                           Earned Run Average (ERA)  Complete Games  Shutouts  \
# Wins                                     -0.819600        0.080533  0.471805
# Runs                                     -0.049281        0.232042 -0.103274
# At Bats                                   0.255551       -0.080876 -0.197321
# Hits                                      0.231172        0.147955 -0.145559
# Doubles                                  -0.254854        0.306675  0.057998
# Triples                                   0.330951       -0.065898 -0.041396
# HomeRuns                                 -0.090917        0.156502 -0.019119
# Walks                                    -0.459832        0.462478  0.426004
# Strike Outs                              -0.180368       -0.093418  0.237721
# Stolen Bases                              0.126063       -0.020783 -0.106563
# Runs Allowed                              0.986674       -0.016659 -0.636862
# Earned Runs                               0.997248       -0.020221 -0.630192
# Earned Run Average (ERA)                  1.000000       -0.009856 -0.630833
# Complete Games                           -0.009856        1.000000  0.241676
# Shutouts                                 -0.630833        0.241676  1.000000
# Saves                                    -0.607005       -0.367766  0.221639
# Errors                                    0.113137       -0.140047 -0.115716
#
#                              Saves    Errors
# Wins                      0.666530 -0.089485
# Runs                     -0.096380 -0.023262
# At Bats                  -0.106367  0.316743
# Hits                     -0.130371 -0.033173
# Doubles                   0.171576  0.105754
# Triples                  -0.142370  0.126678
# HomeRuns                 -0.028540 -0.207597
# Walks                     0.099445 -0.075685
# Strike Outs               0.126297  0.155133
# Stolen Bases             -0.183418  0.079149
# Runs Allowed             -0.616224  0.198996
# Earned Runs              -0.589663  0.136921
# Earned Run Average (ERA) -0.607005  0.113137
# Complete Games           -0.367766 -0.140047
# Shutouts                  0.221639 -0.115716
# Saves                     1.000000 -0.025636
# Errors                   -0.025636  1.000000

# %% [markdown]
# As we have so many columns to read we will read it in graphical representation

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr(), annot=True, cmap='pink_r', linecolor= 'Brown',linewidth= 0.2, square= True)
# Out:
# <AxesSubplot:>

# %% [raw]
# Observation:
#     At bats, triples, stolen bases, Runs allowed, Earned runs, earned Runs average, error have negative correlation with wins.
#     Runs, hits, doubles, homeruns, walk, strikeouts, complete game, shutouts, saves have possitve correlation with wins.
#     negative and badly correlated with wins are: at bats, triples, errors and stolen bases
#     negative and good correlation with wins are: runs allowed, earned runs and earned runs average.
#     positive and badly correlated with wins are: hits, strike out and complete games
#     positive and highly correlated with wins are: runs, doubles saves and shutout

# %% [markdown]
# Lets plot a segregate negative and positive correlated feature columns and compare it with Target column Wins for more better understanding

# %%
plt.figure(figsize=(20,10))
df.corr()['Wins'].sort_values(ascending=False).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# # Checking and Removing Outliers:

# %%
from scipy.stats import zscore
z = np.array(abs(zscore(df)))
threshold = 3
print(np.where(z>3))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))
#     Wins  Runs  At Bats  Hits  Doubles  Triples  HomeRuns  Walks  Strike Outs  \
# 0     95   724     5575  1497      300       42       139    383          973
# 1     83   696     5467  1349      277       44       156    439         1264
# 2     81   669     5439  1395      303       29       141    533         1157
# 3     76   622     5533  1381      260       27       136    404         1231
# 4     74   689     5605  1515      289       49       151    455         1259
# 6     87   764     5567  1397      272       19       212    554         1227
# 7     81   713     5485  1370      246       20       217    418         1331
# 8     80   644     5485  1383      278       32       167    436         1310
# 9     78   748     5640  1495      294       33       161    478         1148
# 10    88   751     5511  1419      279       32       172    503         1233
# 11    86   729     5459  1363      278       26       230    486         1392
# 12    85   661     5417  1331      243       21       176    435         1150
# 13    76   656     5544  1379      262       22       198    478         1336
# 14    68   694     5600  1405      277       46       146    475         1119
# 15   100   647     5484  1386      288       39       137    506         1267
# 16    98   697     5631  1462      292       27       140    461         1322
# 17    97   689     5491  1341      272       30       171    567         1518
# 18    68   655     5480  1378      274       34       145    412         1299
# 19    64   640     5571  1382      257       27       167    496         1255
# 20    90   683     5527  1351      295       17       177    488         1290
# 21    83   703     5428  1363      265       13       177    539         1344
# 22    71   613     5463  1420      236       40       120    375         1150
# 23    67   573     5420  1361      251       18       100    471         1107
# 24    63   626     5529  1374      272       37       130    387         1274
# 25    92   667     5385  1346      263       26       187    563         1258
# 26    84   696     5565  1486      288       39       136    457         1159
# 27    79   720     5649  1494      289       48       154    490         1312
# 28    74   650     5457  1324      260       36       148    426         1327
# 29    68   737     5572  1479      274       49       186    388         1283
#
#     Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average (ERA)  \
# 0            104           641          601                      3.73
# 1             70           700          653                      4.07
# 2             86           640          584                      3.67
# 3             68           701          643                      3.98
# 4             83           803          746                      4.64
# 6             63           698          652                      4.03
# 7             44           693          646                      4.05
# 8             87           642          604                      3.74
# 9             71           753          694                      4.31
# 10           101           733          680                      4.24
# 11           121           618          572                      3.57
# 12            52           675          630                      3.94
# 13            69           726          677                      4.16
# 14            78           729          664                      4.14
# 15            69           525          478                      2.94
# 16            98           596          532                      3.21
# 17            95           608          546                      3.36
# 18            84           737          682                      4.28
# 19           134           754          700                      4.33
# 20            51           613          557                      3.43
# 21            57           635          577                      3.62
# 22           112           678          638                      4.02
# 23            69           760          698                      4.41
# 24            88           809          749                      4.69
# 25            59           595          553                      3.44
# 26            93           627          597                      3.72
# 27           132           713          659                      4.04
# 28            82           731          655                      4.09
# 29            97           844          799                      5.04
#
#     Complete Games  Shutouts  Saves  Errors
# 0                2         8     56      88
# 1                2        12     45      86
# 2               11        10     38      79
# 3                7         9     37     101
# 4                7        12     35      86
# 6                3         4     48      93
# 7                0        10     43      77
# 8                1        12     60      95
# 9                3        10     40      97
# 10               5         9     45     119
# 11               5        13     39      85
# 12               2        12     46      93
# 13               6        12     45      94
# 14               5        15     28     126
# 15               1        15     62      96
# 16               0        13     54     122
# 17               6        21     48     111
# 18               1         7     40     116
# 19               2         8     35      90
# 20               1        14     50      88
# 21               4        13     41      90
# 22               0        12     35      77
# 23               3        10     44      90
# 24               1         7     35     117
# 25               6        21     47      75
# 26               7        18     41      78
# 27               1        12     44      86
# 28               1         6     41      92
# 29               4         4     36      95

# %%
df_new.shape
# Out:
# (29, 17)

# %%
df.shape
# Out:
# (30, 17)

# %%
dataloss= ((30-29)/30)*100
dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# it is considerable amount of data loss so we can proceed

# %% [markdown]
# Lets check the final data after removing outliers

# %%
fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(15,15))
index = 0
features = df_new.drop("Wins", axis=1)
ax = ax.flatten()
for col, value in features.items():
    sns.boxplot(y=col, data=df_new, ax=ax[index], palette='Wistia_r')
    index += 1
plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
plt.show()

# %% [raw]
# As we can see z score has not removed all outliers but i am going these outliers as we cannot afford anymore loss in data because the data is small

# %% [markdown]
# # Checking Skewness:

# %%
df_new.skew().sort_values()
# Out:
# Doubles                    -0.335304
# Strike Outs                -0.233815
# Runs                       -0.215364
# Earned Run Average (ERA)    0.016693
# Runs Allowed                0.018155
# Earned Runs                 0.018461
# Triples                     0.090124
# Wins                        0.119013
# Walks                       0.151193
# At Bats                     0.169573
# HomeRuns                    0.450862
# Stolen Bases                0.494966
# Shutouts                    0.526943
# Saves                       0.627480
# Hits                        0.783772
# Errors                      0.840271
# Complete Games              0.854980
# dtype: float64

# %%
from scipy.stats import skew
for i in df_new:
    print(i, "=", skew(df_new[i]))
    plt.figure(figsize=(10,5))
    sns.histplot(df_new[i], kde = True, color= 'green')
    plt.show()
# Out:
# Wins = 0.11276693557129294
# Runs = -0.20406011203640076
# At Bats = 0.16067299318317793
# Hits = 0.7426353382402017
# Doubles = -0.31770525706395997
# Triples = 0.08539410248772253
# HomeRuns = 0.427197772372019
# Walks = 0.14325736043584017
# Strike Outs = -0.2215429668493466
# Stolen Bases = 0.46898711615548905
# Runs Allowed = 0.017202289030994758
# Earned Runs = 0.017492051216126122
# Earned Run Average (ERA) = 0.01581706170438952
# Complete Games = 0.8101053438609993
# Shutouts = 0.49928605613953103
# Saves = 0.5945467030287168
# Errors = 0.7961689324660232

# %% [raw]
# Observation:
#      wins, runs allowed, earned runs, earned runs average, walks, strike out, at bats doubles, triples , home runs, stolen            bases,all are almost normally distributed
#      error, hits and complete games are slightly skewed

# %% [markdown]
# Lets remove the skewness of hits, complete game and error .But save is highly correlated with wins so removing skewness may reduce its correlation

# %% [markdown]
# # Splitting the Datafrma in features and target columns

# %%
x = df.drop('Wins', axis=1)
y = df['Wins']

# %% [markdown]
# # Scaling Features using standard scaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head(10)
# Out:
#        Runs   At Bats      Hits   Doubles   Triples  HomeRuns     Walks  \
# 0  0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1  0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2 -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3 -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4  0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5  3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6  1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7  0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8 -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9  1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
#
#    Strike Outs  Stolen Bases  Runs Allowed  Earned Runs  \
# 0    -2.697630      0.913883     -0.666234    -0.505110
# 1     0.154878     -0.601826      0.165971     0.248930
# 2    -0.893982      0.111449     -0.680339    -0.751623
# 3    -0.168602     -0.690985      0.180076     0.103922
# 4     0.105866     -0.022290      1.618803     1.597501
# 5    -0.952796      0.200609     -0.257184    -0.389104
# 6    -0.207812     -0.913883      0.137760     0.234429
# 7     0.811641     -1.760897      0.067235     0.147424
# 8     0.605790      0.156029     -0.652129    -0.461608
# 9    -0.982204     -0.557246      0.913544     0.843461
#
#    Earned Run Average (ERA)  Complete Games  Shutouts     Saves    Errors
# 0                 -0.506955       -0.539806 -0.814629  1.671607 -0.461470
# 1                  0.254598       -0.539806  0.172800  0.249879 -0.607197
# 2                 -0.641347        2.772641 -0.320914 -0.654856 -1.117242
# 3                  0.053010        1.300442 -0.567771 -0.784104  0.485758
# 4                  1.531318        1.300442  0.172800 -1.042600 -0.607197
# 5                 -0.350165        1.300442 -0.320914 -1.171848 -0.461470
# 6                  0.165003       -0.171757 -1.802057  0.637623 -0.097152
# 7                  0.209800       -1.275906 -0.320914 -0.008617 -1.262970
# 8                 -0.484557       -0.907856  0.172800  2.188598  0.048576
# 9                  0.792164       -0.171757 -0.320914 -0.396360  0.194303

# %% [markdown]
# Scaling my feature data to ensure there is no biasness over a particular column instead we will have a uniform dataset value.

# %% [markdown]
# # Principle Component Analysis(PCA)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=16, svd_solver="full")
x = pd.DataFrame(pca.fit_transform(x), columns=x.columns)
x
# Out:
#         Runs   At Bats      Hits   Doubles   Triples  HomeRuns     Walks  \
# 0   0.867413  2.122345 -2.894358  0.669670 -2.731243  0.147389  0.635840
# 1   0.130337 -0.870952 -0.351691  0.134231 -0.211433  0.468177 -0.904620
# 2  -1.311442  1.177871  0.666544  2.976226  0.312964 -0.639481  1.136171
# 3   0.765362 -1.377492 -0.051721  0.950416  0.423381 -1.075740  0.063431
# 4   3.323426  1.681766  0.273832  1.260491  0.864381  0.260109 -1.708900
# 5  -0.923627  4.086316  3.319173  0.318585 -1.168070 -0.190317  0.960672
# 6  -0.290468  0.738750  2.201384 -1.446595 -1.693805 -0.599754  0.338534
# 7  -0.593708 -1.961116  1.796415 -1.146524 -1.658562  1.107181 -1.327971
# 8  -1.324598 -0.735104 -1.534594 -1.140173 -0.529206  0.467598 -0.210044
# 9   2.062331  2.069248  0.209600 -0.094183 -0.944075 -0.922906 -0.794728
# 10  1.038273  0.998447  0.689082 -0.882560  0.581442 -1.020031  0.886895
# 11 -2.031802  0.749103  1.432943 -0.614513  1.033535  2.068396  1.043251
# 12 -1.012730 -2.694936  0.633383  0.343571 -1.241014 -0.408135 -0.133344
# 13 -0.089221 -0.732062  1.529029 -0.404961  0.500484 -0.151637 -0.781112
# 14  1.839688  0.837809 -0.422636  0.643194  1.698484 -1.995640 -0.349693
# 15 -3.958160  0.249901 -3.058867 -0.355279 -0.472840 -0.308366 -0.330891
# 16 -1.541806  1.682041 -2.805191 -2.262533  0.212761 -0.971927  0.455043
# 17 -3.545848  0.344579 -0.023515 -0.974677  3.282706 -0.032191 -0.332245
# 18  1.643897 -1.439326 -0.452282 -1.158038  0.385557 -0.811266  0.486600
# 19  1.878965 -0.652828  0.537827 -0.366033  0.895158  1.280984  1.728158
# 20 -2.844429 -0.073285 -0.151029 -0.787096 -1.023046 -0.595840 -0.627829
# 21 -2.674651 -0.879263  1.662271 -0.002001  0.079108 -0.357780  0.110064
# 22  1.324276 -2.216815 -1.820057  1.528869 -0.221029  2.054799  0.701523
# 23  0.891233 -3.226498 -0.157753  1.757975 -0.600831 -1.145005  0.769330
# 24  3.520272 -1.851553 -0.471381 -0.876549  0.822034 -0.969647  0.218706
# 25 -4.067299 -0.742764  0.932156  1.757037  0.504348  0.531124 -0.860665
# 26 -0.438245  1.992377 -1.289557  2.306639  0.283391  0.566028 -0.717905
# 27  1.596051  2.432606 -1.492163 -0.795504  0.699950  1.840486 -0.076881
# 28  0.798713 -2.312637 -0.057334 -0.632012  0.010754  0.498651  0.394409
# 29  4.967798  0.603473  1.150491 -0.707672 -0.095282  0.904741 -0.771799
#
#     Strike Outs  Stolen Bases  Runs Allowed  Earned Runs  \
# 0      0.321777     -0.462272     -0.020176    -0.732738
# 1      0.929330     -0.852782     -0.625750     0.615142
# 2      1.596495      0.234307      0.653205     0.387795
# 3     -0.105279      0.028011      1.593964    -0.540106
# 4      0.463959      0.672309      0.110339     0.065684
# 5     -0.395233     -0.801111     -0.167729     0.314109
# 6      0.008548      0.856549     -0.427661    -0.060139
# 7     -0.739914     -0.320259      0.534286     0.051121
# 8      0.943309      0.293857     -0.171844    -0.675044
# 9     -0.670389      0.536733     -0.138445     0.416838
# 10     0.396999     -0.346111     -0.909708    -0.885510
# 11     0.257422     -0.859763      0.681993    -0.244448
# 12    -0.658749     -0.670554     -0.394176    -0.682118
# 13     0.018792      0.946070      0.509194    -0.941434
# 14    -1.369775     -1.360172     -0.437932     0.199832
# 15     0.675599     -0.079744     -0.431861     0.232928
# 16    -0.880283      0.327744      0.743113    -0.120462
# 17     0.071163      0.112862     -0.334326    -0.365034
# 18     0.550568     -0.680587      0.149492     0.311022
# 19    -0.780736      1.209397     -0.212832     0.182944
# 20    -0.068929      0.379953      0.597044     0.997014
# 21    -0.333308      0.194714      0.175781     0.505552
# 22    -1.336857     -0.569343      0.005902     0.087664
# 23    -0.087775      1.380480     -0.751994    -0.002252
# 24     0.313519     -0.293193      0.161100     0.476022
# 25    -0.148402     -0.050935     -0.950081    -0.203416
# 26    -0.551429      0.101031      0.483098    -0.214313
# 27    -0.236777      0.878712     -0.528927     0.551768
# 28     0.881357     -0.411728      0.099262     0.738144
# 29     0.934998     -0.394176      0.005672    -0.466564
#
#     Earned Run Average (ERA)  Complete Games  Shutouts     Saves    Errors
# 0                   0.145333        0.320717  0.163688 -0.057452 -0.016369
# 1                   0.210456        0.202009  0.448008  0.048235  0.035712
# 2                   0.284388       -0.104070 -0.105921  0.017393 -0.006928
# 3                   0.415591       -0.381558  0.209748 -0.026714  0.019517
# 4                  -0.237473       -0.169029 -0.257682 -0.104577  0.011645
# 5                  -0.605618       -0.004595  0.024952 -0.081558  0.018777
# 6                   0.954141       -0.565738 -0.002555  0.124789  0.007092
# 7                  -0.067460       -0.179533  0.009786 -0.003204 -0.026789
# 8                  -0.235321        0.442357 -0.162970  0.025565 -0.000745
# 9                  -0.119349        0.104018  0.021363 -0.011747 -0.016363
# 10                 -0.309901       -0.183516  0.155475  0.030483  0.007767
# 11                  0.050049        0.524676 -0.171760 -0.002193 -0.021735
# 12                  0.076438        0.156623  0.041471 -0.036549  0.015641
# 13                  0.293047        0.360786 -0.063620 -0.055128  0.023022
# 14                  0.858780        0.266338 -0.161081 -0.017453 -0.025085
# 15                  0.441433       -0.511482 -0.363987  0.011070 -0.008985
# 16                 -0.428924       -0.292350 -0.041474 -0.068937  0.016720
# 17                 -0.193818       -0.192121  0.385296 -0.001882 -0.028476
# 18                 -0.476725       -0.042444 -0.290659  0.078853  0.018104
# 19                  0.596679        0.448110 -0.049179  0.019881  0.005135
# 20                 -0.007339        0.877234  0.079284  0.028654 -0.008483
# 21                 -0.557255       -0.590504 -0.051342  0.055292 -0.007006
# 22                 -0.196625       -0.510302 -0.102310  0.031526  0.010222
# 23                 -0.658450        0.129735  0.090848 -0.039505 -0.032992
# 24                 -0.351659        0.468982 -0.071316  0.059999  0.015665
# 25                  0.015959        0.169668 -0.252409 -0.046467  0.023253
# 26                 -0.238671        0.049380  0.257473  0.180422 -0.000478
# 27                  0.108412       -0.110158  0.104681 -0.035279  0.014038
# 28                  0.357306       -0.394451  0.260075 -0.177748 -0.010214
# 29                 -0.123426       -0.288781 -0.103880  0.054228 -0.031663

# %% [markdown]
# Ideally PCA is used for reducing dimentionality on bigger dataset I am using this to check if it can assist with the skewness of data

# %% [markdown]
# # Power Tranformation

# %%
from sklearn.preprocessing import PowerTransformer
power_t = PowerTransformer(method = 'yeo-johnson')
x = pd.DataFrame(power_t.fit_transform(x), columns=x.columns)
x
# Out:
#         Runs   At Bats      Hits   Doubles   Triples  HomeRuns     Walks  \
# 0   0.390948  1.220062 -1.831168  0.689046 -2.492064  0.260356  0.803720
# 1   0.051054 -0.486263 -0.288787  0.284404 -0.176831  0.563552 -1.143577
# 2  -0.606009  0.700995  0.410973  2.006434  0.290443 -0.604189  1.440320
# 3   0.343751 -0.795417 -0.090142  0.879033  0.387940 -1.149763  0.077610
# 4   1.535074  0.979332  0.132843  1.075942  0.774959  0.369635 -2.153659
# 5  -0.430083  2.271328  2.448961  0.431321 -1.045491 -0.089160  1.216853
# 6  -0.141699  0.455223  1.563611 -1.395092 -1.528988 -0.556598  0.426236
# 7  -0.280020 -1.156618  1.251292 -1.025896 -1.496468  1.111159 -1.675649
# 8  -0.611969 -0.404167 -1.029829 -1.018303 -0.463444  0.563026 -0.268185
# 9   0.945918  1.191166  0.088245  0.087694 -0.840649 -0.954035 -1.005300
# 10  0.470048  0.600977  0.427194 -0.718517  0.527065 -1.077870  1.122964
# 11 -0.931709  0.461058  0.975520 -0.424433  0.922539  1.843832  1.321982
# 12 -0.470545 -1.616919  0.387155  0.450548 -1.112357 -0.332413 -0.171279
# 13 -0.049649 -0.402333  1.047973 -0.208272  0.455867 -0.047354 -0.988162
# 14  0.842232  0.510966 -0.334956  0.670460  1.498938 -2.418619 -0.444484
# 15 -1.797754  0.177029 -1.925594 -0.158910 -0.412445 -0.219389 -0.420757
# 16 -0.710304  0.979483 -1.779789 -2.494328  0.201723 -1.016295  0.574085
# 17 -1.612875  0.231360 -0.071141 -0.823854  2.854457  0.078902 -0.422465
# 18  0.751146 -0.833451 -0.354167 -1.039683  0.354571 -0.814130  0.614148
# 19  0.860515 -0.354633  0.318846 -0.169531  0.801844  1.250434  2.195252
# 20 -1.297794 -0.010464 -0.156572 -0.611616 -0.912781 -0.551930 -0.795145
# 21 -1.221410 -0.491299  1.148985  0.169275  0.082996 -0.275039  0.136655
# 22  0.602665 -1.316298 -1.201603  1.237364 -0.185452  1.834029  0.887203
# 23  0.401969 -1.953930 -0.161045  1.369544 -0.528342 -1.240004  0.973417
# 24  1.627280 -1.088450 -0.366518 -0.711718  0.737944 -1.013388  0.274296
# 25 -1.846654 -0.408786  0.603714  1.369012  0.459269  0.620461 -1.088277
# 26 -0.209159  1.149278 -0.880537  1.668541  0.264283  0.651697 -0.908589
# 27  0.728902  1.388328 -1.004105 -0.620938  0.631063  1.677648 -0.099905
# 28  0.359171 -1.376341 -0.093916 -0.443046  0.022086  0.591198  0.497127
# 29  2.306959  0.378783  0.764557 -0.524482 -0.072675  0.944246 -0.976439
#
#     Strike Outs  Stolen Bases  Runs Allowed  Earned Runs  \
# 0      0.470835     -0.682189      0.064786    -1.434800
# 1      1.327853     -1.340931     -1.209615     1.285151
# 2      2.256420      0.401404      1.170637     0.772887
# 3     -0.140927      0.094505      2.405451    -1.088526
# 4      0.672603      1.021350      0.301689     0.083348
# 5     -0.561648     -1.252014     -0.220058     0.611188
# 6      0.023080      1.271945     -0.763159    -0.172819
# 7     -1.066359     -0.450849      0.993261     0.053293
# 8      1.347429      0.488011     -0.228255    -1.332156
# 9     -0.964201      0.833398     -0.162117     0.837224
# 10     0.577684     -0.492605     -1.894646    -1.702547
# 11     0.379227     -1.352983      1.212676    -0.534767
# 12    -0.947115     -1.029652     -0.690393    -1.344789
# 13     0.037804      1.391881      0.955027    -1.799179
# 14    -1.998694     -2.239077     -0.785638     0.364935
# 15     0.971501     -0.070601     -0.772341     0.435669
# 16    -1.273108      0.536935      1.300835    -0.292907
# 17     0.112987      0.222107     -0.562353    -0.764233
# 18     0.795118     -1.046620      0.370199     0.604464
# 19    -1.126418      1.738484     -0.310625     0.329030
# 20    -0.088474      0.611824      1.087634     2.186386
# 21    -0.471471      0.343358      0.415593     1.035783
# 22    -1.949693     -0.859648      0.113240     0.128903
# 23    -0.115660      1.959191     -1.507844    -0.055952
# 24     0.459089     -0.407306      0.390302     0.969353
# 25    -0.203242     -0.026120     -1.996123    -0.455427
# 26    -0.789806      0.204436      0.914950    -0.476564
# 27    -0.331239      1.301744     -0.988031     1.140406
# 28     1.260630     -0.599310      0.282103     1.570146
# 29     1.335792     -0.570668      0.112815    -0.953496
#
#     Earned Run Average (ERA)  Complete Games  Shutouts     Saves    Errors
# 0                   0.469495        0.906341  0.891370 -0.843992 -0.899919
# 1                   0.619319        0.603753  2.096847  0.715942  2.105289
# 2                   0.782998       -0.235449 -0.514729  0.266037 -0.424704
# 3                   1.058553       -1.077254  1.102911 -0.384977  1.065315
# 4                  -0.543786       -0.425870 -1.449537 -1.555974  0.595888
# 5                  -1.739563        0.047749  0.207038 -1.206959  1.020160
# 6                   2.037734       -1.674454  0.061872  1.814836  0.334627
# 7                  -0.063849       -0.457056  0.127429 -0.036842 -1.393297
# 8                  -0.537417        1.205618 -0.853897  0.385666 -0.098037
# 9                  -0.205275        0.345107  0.188292 -0.163051 -0.899627
# 10                 -0.762466       -0.468913  0.852885  0.457512  0.372908
# 11                  0.239617        1.402602 -0.907469 -0.021927 -1.157910
# 12                  0.304636        0.485019  0.292597 -0.531377  0.831320
# 13                  0.801749        1.006065 -0.272830 -0.809135  1.281717
# 14                  1.878887        0.769100 -0.842429 -0.247540 -1.314730
# 15                  1.110786       -1.495528 -2.166035  0.173264 -0.530647
# 16                 -1.139709       -0.798711 -0.149460 -1.016587  0.895880
# 17                 -0.416035       -0.494574  1.849876 -0.017346 -1.470230
# 18                 -1.297350       -0.058777 -1.666400  1.158414  0.979314
# 19                  1.412049        1.219523 -0.192124  0.302494  0.224623
# 20                  0.094340        2.203283  0.484094  0.430795 -0.504900
# 21                 -1.570733       -1.756935 -0.204154  0.818288 -0.428743
# 22                 -0.424159       -1.491665 -0.493755  0.472733  0.513457
# 23                 -1.927930        0.413823  0.541496 -0.575454 -1.672418
# 24                 -0.892310        1.269797 -0.316230  0.886428  0.832732
# 25                  0.153980        0.519329 -1.415312 -0.679459  1.296175
# 26                 -0.547336        0.197017  1.314849  2.598486 -0.083615
# 27                  0.382001       -0.253116  0.609473 -0.512440  0.736150
# 28                  0.938353       -1.118105  1.326200 -2.680697 -0.593283
# 29                 -0.216578       -0.787720 -0.502869  0.802864 -1.613494

# %% [markdown]
# Using the 'yeo-johnson' method as 'box-cox' can be used only on positive data. Since we do not have much data I am trying not to lose more rows by removing outliers. However if needed we can remove outliers later to increace accuracy of model

# %% [markdown]
# # Checking Multicollinearity:

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['variables']=x.columns
    vif["VIF FACTOR"]= [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

calc_vif(x)
# Out:
#                    variables  VIF FACTOR
# 0                       Runs    1.004794
# 1                    At Bats    1.003077
# 2                       Hits    1.006531
# 3                    Doubles    1.016729
# 4                    Triples    1.004408
# 5                   HomeRuns    1.013887
# 6                      Walks    1.005459
# 7                Strike Outs    1.006921
# 8               Stolen Bases    1.007549
# 9               Runs Allowed    1.011566
# 10               Earned Runs    1.002903
# 11  Earned Run Average (ERA)    1.010028
# 12            Complete Games    1.005399
# 13                  Shutouts    1.006350
# 14                     Saves    1.002015
# 15                    Errors    1.004074

# %% [markdown]
# As we can see all columns VIF factor is less than 10 we can proceed with this data

# %%
x.skew()
# Out:
# Runs                        0.052071
# At Bats                     0.045111
# Hits                        0.048036
# Doubles                    -0.037667
# Triples                     0.102962
# HomeRuns                   -0.016813
# Walks                      -0.000915
# Strike Outs                 0.005807
# Stolen Bases                0.002018
# Runs Allowed                0.027201
# Earned Runs                 0.004203
# Earned Run Average (ERA)    0.033742
# Complete Games              0.036015
# Shutouts                    0.009622
# Saves                      -0.008414
# Errors                     -0.040203
# dtype: float64

# %% [markdown]
# As we can see skewness is also maintained in range +/-0.5 we can proceed further.

# %%
fig, ax = plt.subplots(ncols=4, nrows=4, figsize=(17,15))
index = 0
ax = ax.flatten()
for col, value in x.items():
    sns.histplot(value, ax=ax[index], color="indigo", kde=True)
    index += 1
plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
plt.show()

# %% [markdown]
# We can see almost all feature columns are now normally distributed.

# %% [markdown]
# # Best Random State for Regrssion Models

# %%
max_Accu=0
max_RS=0

for i in range(1, 1000):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    r2 = r2_score(y_test, pred)
    
    if r2>max_Accu:
        max_Accu=r2
        max_RS=i

print("Best r2 score is", max_Accu,"on Random State", max_RS)
# Out:
# Best r2 score is 0.9502660203432547 on Random State 623

# %% [markdown]
# Hence we chose our random state value to be 623

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=623)

# %% [markdown]
# As the data is small i will use maximum data for training and min for testing so that I get better results at predictions

# %% [markdown]
# # Training the data and finding best Model:

# %%
lg  = LinearRegression()
svr = SVR(kernel='rbf')
dtr = DecisionTreeRegressor()
knr = KNeighborsRegressor()
ridr= Ridge(alpha=1e-2, normalize=True)
las = Lasso(alpha=1e-2, normalize=True, max_iter=100)
rfr = RandomForestRegressor()
gbr = GradientBoostingRegressor(loss='quantile', n_estimators=200, max_depth=5)
abr = AdaBoostRegressor(n_estimators=300, learning_rate=1.05, random_state=42)
etr = ExtraTreesRegressor(n_estimators=200, max_features='sqrt', n_jobs=6)


model=[lg,svr,dtr,knr,ridr,las,rfr,gbr,abr,etr]

for m in model:
    print('\n')
    print('******************',m,'*******************')
    print('\n')
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    
    # calculating scores
    train_score=r2_score(y_train,pred_train)
    test_score=r2_score(y_test,pred_test)
    r2 = r2_score(y_test, pred_test)*100
    
    #Calculating cross validation score
   
    for i in range(2,8):
        cvs=cross_val_score(m,x,y,cv=i)
        
    a = max(cvs)
    cv_score=(a.mean())*100    # taking max value of cvs and calculating mean of it    
# taking max value because I am assuming that r2 score of all models to be approx 100 %

    
    # final result comparing r2 and cross validation
    result = r2 - cv_score
    
    
    print('The training accuracy of is', train_score)
    print('The test accuracy of is', test_score)
    print("R2 Score is:", r2)
    print("Cross Validation Scores",cvs)
    print("Maximum of cvs:" , a)
    print("Cross Validation Score:", cv_score)
    print("R2 Score - Cross Validation Score is", result)
    print("Error Calculations:")
    print("Mean absolute error :",mean_absolute_error(y_test,pred_test))
    print("Mean squared error : ",mean_squared_error(y_test, pred_test))
    print("Root mean squared error:", np.sqrt(mean_squared_error(y_test,pred_test)))
    
    plt.figure(figsize=(8,6))
    plt.scatter(x=y_test,y=pred_test,color='r')
    plt.plot(y_test,y_test,color='b')
    plt.xlabel('Actual wins',fontsize=14)
    plt.ylabel('Predicted Wins',fontsize=14)
    plt.title(m,fontsize=18)
    plt.show()
# Out:
# ****************** LinearRegression() *******************
#
#
# The training accuracy of is 0.9296111110539047
# The test accuracy of is 0.9502660203432547
# R2 Score is: 95.02660203432546
# Cross Validation Scores [ 0.65890465 -0.02612517  0.38204256  0.20180344  0.7938578   0.92461063
#  -0.70803731]
# Maximum of cvs: 0.9246106309925379
# Cross Validation Score: 92.46106309925379
# R2 Score - Cross Validation Score is 2.5655389350716717
# Error Calculations:
# Mean absolute error : 2.7048465681821185
# Mean squared error :  10.107049865798578
# Root mean squared error: 3.179158672636296
# ****************** SVR() *******************
#
#
# The training accuracy of is 0.17263443711486026
# The test accuracy of is -0.0898054823986758
# R2 Score is: -8.98054823986758
# Cross Validation Scores [ 0.01465094 -0.19359788 -0.51077928 -0.61616381 -0.15405201 -0.53830443
#  -0.78373419]
# Maximum of cvs: 0.014650939197472956
# Cross Validation Score: 1.4650939197472956
# R2 Score - Cross Validation Score is -10.445642159614877
# Error Calculations:
# Mean absolute error : 13.897040604178128
# Mean squared error :  221.47269192301977
# Root mean squared error: 14.881958605070093
# ****************** DecisionTreeRegressor() *******************
#
#
# The training accuracy of is 1.0
# The test accuracy of is 0.43575724439584473
# R2 Score is: 43.57572443958448
# Cross Validation Scores [-0.26292467 -1.5331565  -9.83185841 -0.03778338  0.66869133  0.03744383
#   0.3250444 ]
# Maximum of cvs: 0.6686913307564881
# Cross Validation Score: 66.86913307564882
# R2 Score - Cross Validation Score is -23.293408636064342
# Error Calculations:
# Mean absolute error : 9.333333333333334
# Mean squared error :  114.66666666666667
# Root mean squared error: 10.708252269472673
# ****************** KNeighborsRegressor() *******************
#
#
# The training accuracy of is 0.40956163458291106
# The test accuracy of is -0.2058392564242757
# R2 Score is: -20.58392564242757
# Cross Validation Scores [ 0.3521418   0.32201592 -2.89710914 -0.50528967  0.12313639 -0.4476685
#  -0.78955595]
# Maximum of cvs: 0.352141802067947
# Cross Validation Score: 35.2141802067947
# R2 Score - Cross Validation Score is -55.79810584922227
# Error Calculations:
# Mean absolute error : 14.533333333333337
# Mean squared error :  245.05333333333337
# Root mean squared error: 15.654179420631838
# ****************** Ridge(alpha=0.01, normalize=True) *******************
#
#
# The training accuracy of is 0.9291695668090444
# The test accuracy of is 0.9269350891056114
# R2 Score is: 92.69350891056114
# Cross Validation Scores [ 0.67866697 -0.01459695  0.37248624  0.25548929  0.80143928  0.93481381
#  -0.63578967]
# Maximum of cvs: 0.9348138067326579
# Cross Validation Score: 93.48138067326579
# R2 Score - Cross Validation Score is -0.7878717627046541
# Error Calculations:
# Mean absolute error : 3.235635991818768
# Mean squared error :  14.848413558426307
# Root mean squared error: 3.853363927586688
# ****************** Lasso(alpha=0.01, max_iter=100, normalize=True) *******************
#
#
# The training accuracy of is 0.927578945518489
# The test accuracy of is 0.8849888752818744
# R2 Score is: 88.49888752818744
# Cross Validation Scores [ 0.66469109  0.01396764  0.33849317  0.36438952  0.82737943  0.93636831
#  -0.13392606]
# Maximum of cvs: 0.9363683079315931
# Cross Validation Score: 93.6368307931593
# R2 Score - Cross Validation Score is -5.137943264971867
# Error Calculations:
# Mean absolute error : 4.187450869868389
# Mean squared error :  23.37281634549464
# Root mean squared error: 4.834544068006273
# ****************** RandomForestRegressor() *******************
#
#
# The training accuracy of is 0.8912906720702465
# The test accuracy of is 0.45881894477856766
# R2 Score is: 45.88189447785677
# Cross Validation Scores [-0.15849151 -0.18433223 -2.96126726  0.17372407  0.6869862   0.27262806
#   0.22273535]
# Maximum of cvs: 0.6869861954721148
# Cross Validation Score: 68.69861954721148
# R2 Score - Cross Validation Score is -22.81672506935471
# Error Calculations:
# Mean absolute error : 9.418333333333331
# Mean squared error :  109.98001666666664
# Root mean squared error: 10.48713577039349
# ****************** GradientBoostingRegressor(loss='quantile', max_depth=5, n_estimators=200) *******************
#
#
# The training accuracy of is 0.027888434188166555
# The test accuracy of is -0.1523475377010639
# R2 Score is: -15.23475377010639
# Cross Validation Scores [-0.20383711  0.06137483 -0.06204391 -0.07123159 -0.6041293  -0.95846351
#  -1.79273271]
# Maximum of cvs: 0.06137482555542351
# Cross Validation Score: 6.13748255554235
# R2 Score - Cross Validation Score is -21.372236325648743
# Error Calculations:
# Mean absolute error : 12.622397129301895
# Mean squared error :  234.18262738391618
# Root mean squared error: 15.303026739306057
# ****************** AdaBoostRegressor(learning_rate=1.05, n_estimators=300, random_state=42) *******************
#
#
# The training accuracy of is 0.9934556888836814
# The test accuracy of is 0.3969004875536014
# R2 Score is: 39.69004875536014
# Cross Validation Scores [-0.17871388 -0.29340227 -2.77628319  0.07358678  0.71780784  0.25230497
#  -0.11853667]
# Maximum of cvs: 0.717807840971839
# Cross Validation Score: 71.7807840971839
# R2 Score - Cross Validation Score is -32.09073534182376
# Error Calculations:
# Mean absolute error : 9.942424242424243
# Mean squared error :  122.56322314049588
# Root mean squared error: 11.07082757252121
# ****************** ExtraTreesRegressor(max_features='sqrt', n_estimators=200, n_jobs=6) *******************
#
#
# The training accuracy of is 1.0
# The test accuracy of is 0.24271448195735368
# R2 Score is: 24.271448195735367
# Cross Validation Scores [ 0.21820587  0.09474569 -0.89243363 -0.20013947  0.37721088  0.32524463
#  -0.00204796]
# Maximum of cvs: 0.3772108779679736
# Cross Validation Score: 37.721087796797356
# R2 Score - Cross Validation Score is -13.449639601061989
# Error Calculations:
# Mean absolute error : 11.760833333333332
# Mean squared error :  153.89724583333333
# Root mean squared error: 12.405532871800926

# %% [markdown]
# Lets Make a Performace table:

# %%
Performance_table=pd.DataFrame({'Model':['LR','SVR','DTR','KNR','ridge','lasso','RFR','GBR','ABR','ETR'],
           'Trainig Score':[0.92,0.17,1,0.40,0.92,0.92,0.02,0.05,0.99,1],
           'Testing score':[0.95,-0.08,0.43,-0.20,0.92,0.88,0.45,-0.15,0.39,0.24],                      
            'R2 Score': [95.02,-8.98,43.57,-20.58,92.9,88.49,45.88,-15.23,39.6,24.27],
            'CV Score': [92.46,1.46,66.86,35.21,93.48,93.63,68.69,6.13,71.78,37.72],
            'Result' :[2.56,-10.44,-23.29,-55.79,-0.78,-5.13,-22.86,-21.37,-32.09,-13.44],
           'RMSE':[3.17,14.88,10.70,15.65,3.8,4.83,10.48,15.30,11.07,12.40],
            'MSE':[10.10,221.47,114.6,245.05,14.84,23.37,109.98,234.18,122.56,153.89]})

# %%
Performance_table
# Out:
#    Model  Trainig Score  Testing score  R2 Score  CV Score  Result   RMSE  \
# 0     LR           0.92           0.95     95.02     92.46    2.56   3.17
# 1    SVR           0.17          -0.08     -8.98      1.46  -10.44  14.88
# 2    DTR           1.00           0.43     43.57     66.86  -23.29  10.70
# 3    KNR           0.40          -0.20    -20.58     35.21  -55.79  15.65
# 4  ridge           0.92           0.92     92.90     93.48   -0.78   3.80
# 5  lasso           0.92           0.88     88.49     93.63   -5.13   4.83
# 6    RFR           0.02           0.45     45.88     68.69  -22.86  10.48
# 7    GBR           0.05          -0.15    -15.23      6.13  -21.37  15.30
# 8    ABR           0.99           0.39     39.60     71.78  -32.09  11.07
# 9    ETR           1.00           0.24     24.27     37.72  -13.44  12.40
#
#       MSE
# 0   10.10
# 1  221.47
# 2  114.60
# 3  245.05
# 4   14.84
# 5   23.37
# 6  109.98
# 7  234.18
# 8  122.56
# 9  153.89

# %% [markdown]
# We will directly reject model giving negative CV score value.
# From seeing above table we can between lasso, redge and linear but I chose linear regression as best fitted model because it has less value of error when mse and rmse is compared and also considerable difference in cv and r2 score

# %% [markdown]
# # Hypertuning

# %%
# Choosing Linear Regression

final_model_param = {'fit_intercept' : [True, False],
              'normalize' : [True, False],
              'copy_X' : [True, False],   
              'n_jobs' : [-1, 1,  None]
             }

# %%
GSV = GridSearchCV(LinearRegression(), final_model_param, cv=5)
GSV.fit(x_train,y_train)
GSV.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': -1, 'normalize': True}

# %%
Final_Model = LinearRegression(copy_X=True, fit_intercept= True, n_jobs=-1, normalize=True)
Classifier = Final_Model.fit(x_train, y_train)
final_model_pred = Final_Model.predict(x_test)
final_model_r2 = r2_score(y_test, final_model_pred)*100
print("R2 score for the Best Model is:", final_model_r2)
# Out:
# R2 score for the Best Model is: 95.0266020343255

# %% [markdown]
# # Visualizing Final Model

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=final_model_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Sales',fontsize=14)
plt.ylabel('Predicted Sales',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(Final_Model,'BaseBall.obj')
# Out:
# ['BaseBall.obj']

# %% [markdown]
# # Thank You for Evaluating my Project
